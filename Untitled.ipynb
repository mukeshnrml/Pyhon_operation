# %%
import matplotlib.pyplot as plt
x = [80,85,90,95,75,60]
plt.figure(figsize=(4,5))
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f90dca3090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f90dcac690>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f90dca2410>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f90dcad2d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f90dca3c90>],
#  'means': []}

# %%
import numpy as np
df = np.random.randint(40,70,50)
df
# Out:
# array([65, 56, 47, 44, 51, 40, 66, 62, 43, 57, 67, 58, 49, 69, 40, 40, 51,
#        42, 62, 56, 48, 69, 61, 49, 40, 67, 60, 68, 50, 62, 60, 56, 60, 45,
#        62, 47, 64, 62, 63, 66, 67, 64, 67, 67, 63, 41, 65, 50, 49, 58])

# %%
df1=[65, 56, 47, 44, 51, 40, 66, 62, 43, 57, 67, 58, 49, 69, 40, 40, 51,
       42, 62, 56, 48, 69, 61, 49, 40, 67, 60, 68, 50, 62, 60, 56, 60, 45,
       62, 47, 64, 62, 63, 66, 67, 64, 67, 67, 63, 41, 65, 50, 49, 58]
plt.figure(figsize=(4,2))
plt.boxplot(df1,vert=False)
plt.show()

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
