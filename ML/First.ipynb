# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Data Mining and Cleaning 
df = pd.read_csv('plot.csv')
df
# Out:
#    Plot   Rate
# 0   100  15000
# 1   150  20000
# 2   200  25000
# 3   250  30000
# 4   300  35000
# 5   350  40000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Plot    6 non-null      int64
#  1   Rate    6 non-null      int64
# dtypes: int64(2)
# memory usage: 228.0 bytes

# %%
df.head()
# Out:
#    Plot   Rate
# 0   100  15000
# 1   150  20000
# 2   200  25000
# 3   250  30000
# 4   300  35000

# %%
x = [100,150,200,250,300]
y = [20000,30000,40000,50000,25000]
plt.scatter(x,y)

# %%
plt.scatter(df['Rate'],df['Plot'])

# %%
#machine Learning 
a = linear_model.LinearRegression()
a.fit(df[['Rate']],df['Plot'])
# Out:
# LinearRegression()

# %%
a
# Out:
# LinearRegression()

# %%
df_1 = df.drop('Rate', axis=1)
df_1
# Out:
#    Plot
# 0   100
# 1   150
# 2   200
# 3   250
# 4   300
# 5   350

# %%
df_2 = df['Rate']
df_2
# Out:
# 0    15000
# 1    20000
# 2    25000
# 3    30000
# 4    35000
# 5    40000
# Name: Rate, dtype: int64

# %%
b = linear_model.LinearRegression()
b.fit(df_1,df_2)
# Out:
# LinearRegression()

# %%
b.predict([[1000]])
# Out:
# C:\Users\ses6\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([105000.])

# %%
a.coef_
# Out:
# array([0.01])

# %%
a.intercept_
# Out:
# -50.000000000000114

# %%
c = pd.read_csv('plot1.csv')
c
# Out:
#     Plot
# 0    333
# 1    458
# 2    657
# 3    543
# 4   1289
# 5   5541
# 6    847
# 7   1794
# 8    805
# 9    581
# 10  1104
# 11  1310
# 12   899

# %%
b.predict(c)
# Out:
# array([ 38300.,  50800.,  70700.,  59300., 133900., 559100.,  89700.,
#        184400.,  85500.,  63100., 115400., 136000.,  94900.])

# %%
d = b.predict(c)

# %%
c['estimation']= d

# %%
c.to_csv('prection.csv',index=False)

# %%
plt.scatter(df['Plot'],df['Rate'])
plt.plot(df[['Plot']])

# %%
df_f = pd.read_csv('prection.csv')
plt.scatter(df_f['Plot'],df_f['estimation'])

# %% [markdown]
# 25/10/2023
